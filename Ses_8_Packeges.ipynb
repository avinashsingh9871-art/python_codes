# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
#Rmesh is a good std
#he developed an additional code
# it's worked very well
# Ramesh later realised this added code no one can develop
# Ramesh has to charity that code
# He decided to hand over this code to enter world
#he connected  to the Anaconda company 
## whoever installs the software automatically, this code comes to their laptop
# Anaconda agreed
#give me the code vi package, which is a .py code
# to call that package, we need to import it
#What is a Package in Python?

👉 A package is a collection of modules (Python files) organised in folders.

Module = single .py file

Package = folder containing multiple modules

👉 It helps to organise code properly in large projects.
    Real-Life Example

Think like this:

Folder = Package

Files inside folder = Modules

Example:

my_project/
│
├── math_operations/
│   ├── add.py
│   ├── sub.py
│
├── main.py

Here:

math_operations → Package

add.py, sub.py → Modules

# %%
import random

# %%
#module name is math
import math

# %%
#model name is time
import time

# %%
#MODEL NAME = CV2
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #MODEL NAME = CV2
# ----> 2 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
random
# Out:
# <module 'random' from 'C:\\Users\\avina\\anaconda3\\Lib\\random.py'>

# %%
#case 1
import Addition
import sub
import mul
import div
#case 2
import arthumatic

# %%
#telephone directory
import random # module
dir(random) # all the functions and method names will come
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
#setp 1 
#import <model_name>
#step 2
#dir(modual_name)

# %%
#kid: randint
random randint
random random

# %%
randint
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 randint
#
# NameError: name 'randint' is not defined

# %%
import random # module
dir(random) # all the functions and method names will come
random.randint
#step 1: import moduleName
#step 2: dir(modulename)
#step 3: modulename.methodname
# Out:
# <bound method Random.randint of <random.Random object at 0x000001DEA7F6E9A0>>

# %%
import random # module
dir(random) # all the functions and method names will come
random.virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 import random # module
#       2 dir(random) # all the functions and method names will come
# ----> 3 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
random.randintt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 random.randintt
#
# AttributeError: module 'random' has no attribute 'randintt'

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
#telephone directory
import random # module
dir(random)
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
import random # module
dir(random)
random.randint(20,40)
# Out:
# 30

# %%
random.randint(40,500)
# Out:
# 307

# %%
#stpe 1: import modela name
#step 2: Dir ( model name)
#setp 3: Modulename.function name or methodname
#step-4: help (model name.method name)
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(10,20)
# Out:
# 15

# %%
help(random.random)
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
random.random()
# Out:
# 0.6322489966220093

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(23,45)
# Out:
# 32

# %%
random
# Out:
# <module 'random' from 'C:\\Users\\avina\\anaconda3\\Lib\\random.py'>

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
#step 1
#import Modeual_name
#setp 2
#dir(modeual name)

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001DEA7F6E9A0>>

# %%
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
random.randint(30,50)
# Out:
# 35

# %%
random.random()
# Out:
# 0.513788335036995

# %%
randint()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 randint()
#
# NameError: name 'randint' is not defined

# %%
n1=500
n2=700
import random
random.randint(n1,n2)

#step1: import Modualname
#step 2 dir(modulename)
#step3 modulename.methodname
# Out:
# 543

# %%
import random
dir(random)
random.randint(n1,n2)
# Out:
# 675

# %%
random.virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
#if the function is not avilable in the module you will get the attribuite error where you need to check modual using (dir())

# %%
#what is th use of function for that we can use "help(random.randint)

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(30,60)
# Out:
# 36

# %%
#step 1: import modulename
#step 2: dir(moduulname)
#modulename.methodname
#help(modualname.methodname)
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(30,40)
# Out:
# 36

# %%
help(random.random)
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
random.random()
# Out:
# 0.6767134605209199

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001DEA7F6E9A0>>

# %%
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(30,50)
# Out:
# 48

# %%
** module not found error**
-What is the module? It is a single .py file that contains 
-methods
-function
-variables 
-classes(oops concept)
** pacakage**
Its collection of modules
collection of .py files
**analogy**
-assume that the module is a gift
A package is a collection of gifts

# %%
**method VS functions**
-method and functions bot are defined for some task with some name
-but the method is defined under one class,  and the function is defined outside the class
**analogy**
Ramesh, an AI engineer for some task, is working for MongoDB, so first, you need to talk to MongoDB to connect Ramesh
Suresh freelancer, where you can connect directly

# %%
** Two main errors**
-module not found error
-means it's not installed on our machine'
-attribute error
-means the modules have a function method and variables
-that are not available under this module
** Whenever you see an attribute error, perform the Dir module name**

# %%
import random

# %%
random.randint(30,60)
#if we use tab, then we can avoid Dir
#if we observed a bound method or function error
# Out:
# 40

# %%
random.random()
#to avoid help, we can use shift+tab

# %%
random.randint(20,60)
# Out:
# 54

# %%
#[10,20]#include 10 and 20 both are included
#(10,20) exclude

# %%
random.randint(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 random.randint(10)
#
# TypeError: Random.randint() missing 1 required positional argument: 'b'

# %%
random.random(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 random.random(10)
#
# TypeError: Random.random() takes no arguments (1 given)

# %%
#modulename    Method name
#random         randint
#random         random
#random         choice  inside provides the list of values ( a sequence needs to provide, like a list, a tuple, or a string)
#random         shuffle inside the list of values

#math            pi
#math           e
#math           pow
#math            sin

#time           sleep

#os             getcwd
#os             make dir

#keyword        kwlist

#string         ascii upper
#string         ascii lower
#string         punctuations

# %%
random.choice()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 random.choice()
#       2 help(random.choice)
#
# TypeError: Random.choice() missing 1 required positional argument: 'seq'

# %%
help(random.choice)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %%
random.choice(sequence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 random.choice(sequence)
#
# NameError: name 'sequence' is not defined

# %%
number=[10,20,30,40]
random.choice(number)
random.shuffle(number)
print(number)
# Out:
# [30, 10, 20, 40]

# %%
random.shuffle(number)

# %%
import math

# %%
math.pi
help(math.pi)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating-point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
# ...

# %%
math.e
help(math.e)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating-point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
# ...

# %%
help(math.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
help(math.sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
import time

# %%
time.sleep(5)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\avina\\OneDrive\\Naresh IT\\Python 1 Basic'

# %%
help(os.makedirs)
# Out:
# Help on function makedirs in module os:
#
# makedirs(name, mode=511, exist_ok=False)
#     makedirs(name [, mode=0o777][, exist_ok=False])
#
#     Super-mkdir; create a leaf directory and all intermediate ones.  Works like
#     mkdir, except that any intermediate path segment (not just the rightmost)
#     will be created if it does not exist. If the target directory already
#     exists, raise an OSError if exist_ok is False. Otherwise no exception is
#     raised.  This is recursive.

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import string

# %%
string.ascii_uppercase("AVINASH")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 string.ascii_uppercase("AVINASH")
#
# TypeError: 'str' object is not callable

# %%
help(string.ascii_uppercase)
# Out:
# No Python documentation found for 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
random.choice([1,2,3,4])
# Out:
# 4

# %%
random.shuffle
# Out:
# <bound method Random.shuffle of <random.Random object at 0x000001DEA7F6E9A0>>

# %%
random.shuffle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 random.shuffle()
#
# TypeError: Random.shuffle() missing 1 required positional argument: 'x'

# %%
help(random.shuffle)
# Out:
# Help on method shuffle in module random:
#
# shuffle(x) method of random.Random instance
#     Shuffle list x in place, and return None.

# %%
random.shuffle(number)
print(f"shuffle is{number}")
# Out:
# shuffle is[10, 30, 20, 40]

# %%
random.shuffle
# Out:
# <bound method Random.shuffle of <random.Random object at 0x000001DEA7F6E9A0>>

# %%
list=[1,4,6,7,8]
random.shuffle(list)
print(list)
# Out:
# [4, 6, 7, 8, 1]

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# math.e

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pow
# Out:
# <function math.pow(x, y, /)>

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.sin
# Out:
# <function math.sin(x, /)>

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
import time

# %%
time.sleep(3)
print('Hit')
# Out:
# Hit

# %%
import os

# %%
os.makedirs('Avinash')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 os.makedirs('Avinash')
#
# File ~\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Avinash'

# %%
os.makedirs('Avinash',exist_ok=True)

# %%
import string

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
