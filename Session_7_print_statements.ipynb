# %% [markdown]
# **print Statements**

# %%
-why we use this? only to see the outputs
-if we do not print is not an error we are just not able to see teh answers

# %%
number=100 # its not error

# %%
print(number)
# Out:
# 100

# %%
import os

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\avina\\OneDrive\\Naresh IT\\Python 1 Basic'

# %%
import viart
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import viart
#
# ModuleNotFoundError: No module named 'viart'

# %%
n1=100
n2=200
print(n1,n2)
# Out:
# 100 200

# %%
print(100)
print(100,200)
print(100,200,300)
print(100,200,300,400)
# Out:
# 100
# 100 200
# 100 200 300
# 100 200 300 400

# %%
print(n1,n2,300)
print('n1','n2',300)
print('n1',n1,'n2',n2,'apple')
print('n1',n1,'n2',n2,apple)
# Out:
# 100 200 300
# n1 n2 300
# n1 100 n2 200 apple
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 print('n1','n2',300)
#       3 print('n1',n1,'n2',n2,'apple')
# ----> 4 print('n1',n1,'n2',n2,apple)
#
# NameError: name 'apple' is not defined

# %%
print('n1=',n1,'and','n2=',n2)
#n1=100 and n2=200
# Out:
# n1= 100 and n2= 200

# %%
n1=100
n2=200
add=n1+n2
print('the addition of', n1, 'and' n2,' is', add) #every str and variable you need to separate by ","
# Out:
#   Cell In[21], line 4
#     print('the addition of', n1, 'and' n2,' is', add) #every str and variable you need to separate by ","
#                                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
n1=100
n2=200
add=n1+n2
print('the addition of', n1, 'and', n2,' is', add)
# Out:
# the addition of 100 and 200  is 300

# %%
n1=100
n2=200
n3=500
add=n1+n2+n3
print('the addision of n1, n2 and n3 will be add')
print('the addision of', n1,',', n2, 'and', n3, 'will be', add)
# Out:
# the addision of n1, n2 and n3 will be add
# the addision of 100 , 200 and 500 will be 800

# %%
Name=input('Enter your Name:')
age=int(input('Enter you age:'))
City=input('Enter your City Name:')
print('My Name is',Name,'i am ',age,'years old and i came from',City)
# Out:
# Enter your Name: Avinash Singh
# Enter you age: 39
# Enter your City Name: Delhi
# My Name is Avinash Singh i am  39 years old and i came from Delhi

# %% [markdown]
# **Half Even number**

# %%
round(1.5),round(2.5),round(3.5),round(4.5)
#1 or 2      2 or 3    3 or 4     4 or 5 eving time round is chossing even number that is why its call half even number
# Out:
# (2, 2, 4, 4)

# %% [markdown]
# ** format Method**

# %%
n1=100
n2=200
add=n1+n2
add
print('the addition of {} and {} is {}'.format(n1,n2,add))
# Out:
# the addition of 100 and 200 is 300

# %% [markdown]
# #this is the format method where in the print statement in between we need to {} brackets and at the last we need to add.format () and under brackets give variable names,' separation

# %%
Name=input('Enter your Name:')
age=int(input('Enter you age:'))
City=input('Enter your City Name:')
print('my name is {} my age is {} and i am from {}'.format(Name,age,City))
# Out:
# Enter your Name: Avinash Singh
# Enter you age: 39
# Enter your City Name: Delhi
# my name is Avinash Singh my age is 39 and i am from Delhi

# %%
int(5.9)
# Out:
# 5

# %%
a='10'
b=5
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 a='10'
#       2 b=5
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **f-string**

# %%
n1=100
n2=200
add=n1+n2
add
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# the addition of 100 and 200 is 300

# %%
Name=input('Enter your Name:')
age=int(input('Enter you age:'))
City=input('Enter your City Name:')
print(f'my name is {Name} my age is {age} and i am from {City}')
# Out:
# Enter your Name: Avinash
# Enter you age: 39
# Enter your City Name: Noida
# my name is Avinash my age is 39 and i am from Noida

# %% [markdown]
# **F-string is the method where at the staing of the String we can add 'f' and under {} we can give veribales**

# %%
-print('My Name is',Name,'i am ',age,'years old and i came from',City)
-print('my name is {} my age is {} and i am from {}'.format(Name,age,City))
-print(f'my name is {Name} my age is {age} and i am from {City}')
#all three methods to do print

# %%
n1=100
n2=200
add=n1+n2
print('the addition of {} + {} is {}'.format(n1,n2,add))
# Out:
# the addition of 100 + 200 is 300

# %%
n1=100
n2=200
add=n1+n2
print(f'the addition of {n1} + {n2} is {add}')
# Out:
# the addition of 100 + 200 is 300

# %%
#5*7=35
n1=5
n2=7
f'{n1}*{n2}={n1*n2}'
# Out:
# '5*7=35'

# %% [markdown]
# **end oprater if you like to give vartical not horigental anser using print**
# #multiple print statment valuse attached togather

# %%
print(3,end='==>')
print(4,end='===>')
print(5)
# Out:
# 3==>4===>5

# %%
print(Name,end='==>')
print(age,end='===>')
print(City)
# Out:
# Avinash==>39===>Noida

# %%
print(3,4)# 3-->4
print(3,end='--->')
print(4)
# Out:
# 3 4
# 3--->4

# %%
print(3,'--->',4)
# Out:
# 3 ---> 4

# %%
f'{3}--->{4}--->{5}'
# Out:
# '3--->4--->5'

# %% [markdown]
# **seprater sep**

# %%
print(3,4,5,sep='--->')
# Out:
# 3--->4--->5

# %%
# wap ask the user to calculate the area of a triangle
# pi=3.14
# radius=20
# area=pi*radius*radius
pi=3.24
radius=20
area=pi*radius*radius
print(f'area of traingle={pi}*{radius}*{radius}={round(area,2)}')
# Out:
# area of traingle=3.24*20*20=1296.0

# %%
#wap calculate the area of right angle traingle
# area=0.5*breadth*height
b=20
h=10
area=0.5*b*h
print(f'area of right angle {0.5}*{b}*{h}={area}')
# Out:
# area of right angle 0.5*20*10=100.0

# %%
Bill_amt=input('give the bill amount:')
tip_amt=input('give the tip amt:')
Total_amt=float(Bill_amt)+float(tip_amt)
print('total bill where the bill amount{}+tip amount{}=total amt{}'.format(Bill_amt,tip_amt,Total_amt))
# Out:
# give the bill amount: 400.4
# give the tip amt: 500.6
# total bill where the bill amount400.4+tip amount500.6=total amt901.0

# %%
Sal=400000
Tax_paercent=20
Tax=Sal*Tax_paercent/100
print(f'calculated tax amount will be where Salary={Sal},Tax%={Tax_paercent} and based on that total tax will be {Sal}*{Tax_paercent}/100={Tax}')
# Out:
# calculated tax amount will be where Salary=400000,Tax%=20 and based on that total tax will be 400000*20/100=80000.0
