# %% [markdown]
# **TypeCasting**

# %%
-typecast means covert on data type to another datatype
-int to str
-str to int

# %%
10+20
# Out:
# 30

# %%
'10'+'20' #to convert to number we nee dto use type casting
# Out:
# '1020'

# %% [markdown]
# ** int to other data type**
# -int to flot
# -int to str
# -int to bool

# %%
n1=100
type(n1)
# Out:
# int

# %%
float_n1=float(n1)
type(float_n1),float_n1
# Out:
# (float, 100.0)

# %%
str_n1=str(n1)
type(str_n1),str_n1
# Out:
# (str, '100')

# %%
bool_n1=bool(n1)
type(bool_n1),bool_n1
# Out:
# (bool, True)

# %%
float(-100),str(-100),bool(-100)
# Out:
# (-100.0, '-100', True)

# %% [markdown]
# ** float to other data types**

# %%
int(10.5), str(10.5),bool(10.5)
# Out:
# (10, '10.5', True)

# %%
int(-10.5), str(-10.5),bool(-10.5)
# Out:
# (-10, '-10.5', True)

# %%
bool(0.0)
# Out:
# False

# %%
int(-0.0), str(-0.0),bool(-0.0)
# Out:
# (0, '-0.0', False)

# %% [markdown]
# *str to other data types**

# %%
'10','100.5','apple'
# Out:
# ('10', '100.5', 'apple')

# %%
int('10'),float('10'),bool('10')
# Out:
# (10, 10.0, True)

# %%
int('100.5'),float('100.5'),bool('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int('100.5'),float('100.5'),bool('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %% [markdown]
# Float has higest data type level , float is the boss

# %%
int('apple'),float('apple'),bool('apple')
#error        error             true

# %%
int('0'),float('0'),bool('0')
# Out:
# (0, 0.0, True)

# %%
len('apple')
# Out:
# 5

# %%
len('0')
# Out:
# 1

# %%
len('')
# Out:
# 0

# %%
int('0'),float('0'),bool('')
# Out:
# (0, 0.0, False)

# %%
int(100.5)
# Out:
# 100

# %% [markdown]
# **bool to other data types**

# %%
int(True),float(True),str('true'),int(False),float(False),str('Fasle')
# Out:
# (1, 1.0, 'true', 0, 0.0, 'Fasle')
