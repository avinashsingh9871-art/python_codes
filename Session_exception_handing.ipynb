# %% [markdown]
# **Exception handling**

# %%
-exception handling is a mechanisum to handel the error very efficient way
-usually we will write many lnumber of lines in paython codes
-paython is seqentional process, if we face an error at particula line then remening lines will not be executed
-sometimes the error lines might not be important, it is more offen infra related errors it dows not harmfull for our .py script
-in this situation we want to continue the execution 
-exception handling catch the errors effcient way without crash or block the program

# %%
a=10
print(a)
b=20
print(b)
c=a+d #wrong
print(c)
e=100
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 b=20
#       4 print(b)
# ----> 5 c=a+d #wrong
#       6 print(c)
#       7 e=100
#
# NameError: name 'd' is not defined

# %% [markdown]
# #two block we have
# **try block**

# %%
-original code will write here only

# %% [markdown]
# **except block**

# %%
-error will catch here
-if wrror happend python execute the except block code line

# %%
**Name error**
-Veribale missing
**Value error**
** Type error**
  -worng data type
**zerodivisioonerror**
**Model not found error**
** atribuitre errro**
  -mathod not avilable

# %%
#name error
a=10
b=30
print(a)
print(c)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 b=30
#       4 print(a)
# ----> 5 print(c)
#
# NameError: name 'c' is not defined

# %%
num = int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 num = int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
float(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 float(abc)
#
# NameError: name 'abc' is not defined

# %%
print(abc+int(10.55))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(abc+int(10.55))
#
# NameError: name 'abc' is not defined

# %%
result = "10" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = "10" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
100/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 100/0
#
# ZeroDivisionError: division by zero

# %%
import random
random.virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
cv2.virat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cv2.virat
#
# NameError: name 'cv2' is not defined

# %%
model="gpt-10-super"

# %%
import randam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import randam
#
# ModuleNotFoundError: No module named 'randam'

# %%
## correct code try block
n1=eval(input('enter a number1:'))
n2=eval(input('enter a number2:'))
add=n1+n2
print(f'the addttion of {n1} and{n2} is {add}')
# Out:
# enter a number1: 20
# enter a number2: 30
# the addttion of 20 and30 is 50

# %%
try:
    n1=eval(input('enter a number1:'))
    n2=eval(input('enter a number2:'))
    add=n1+n22
    print(f'the addttion of {n1} and{n2} is {add}')
except Exception as e:
    print(e)
# Out:
# enter a number1: 20
# enter a number2: 20
# name 'n22' is not defined

# %%
try:
    n1=eval(input('enter a number1:'))
    n2=eval(input('enter a number2:'))
    add=n1+n22
    print(f'the addttion of {n1} and{n2} is {add}')
except Exception as e:
    print(e)
    print("hi")
# Out:
# enter a number1: 30
# enter a number2: 30
# name 'n22' is not defined
# hi

# %%
try:
    n1=20+'apple'
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    int('10.5')
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: '10.5'

# %%
try:
    import random
    random.choice
except Exception as e:
    print(e)

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
try:
    import random
    random.randint(10)
except Exception as e:
    print(e)
# Out:
# Random.randint() missing 1 required positional argument: 'b'

# %% [markdown]
# **try--except--finally**

# %%
try=== original code
expect== error catching
finally== default block (finally block always runs irrespective of try and expect)

# %%
#try:
   #connection established
   #making tea
#except:
    #connection is not established
    #bad tea
#finally: it's a default block
       # close the connection
       #clan the deck

# %%
try:
    print("good")
    print("connection establised")
except Exception as e:
    print('not good')
    print('connection not establisded')
finally:
    print('anyways')
    print("connection closed")
# Out:
# good
# connection establised
# anyways
# connection closed

# %%
try:
    print(paython)
    print("good")
    print("connection establised")
except Exception as e:
    print('not good')
    print('connection not establisded')
finally:
    print('anyways')
    print("connection closed")
# Out:
# not good
# connection not establisded
# anyways
# connection closed
