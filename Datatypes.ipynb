# %%
-In Python, we have some built-in data types available
1-integer = int
2-float
3-bool
4-string:str
5-list
6-tuple
7-dictionary: dict
8-complex
9-range
10-set
11-frozenset
12-complex
13-bytes
14-bytearray
15-memoryview
16-None

# %%
n1=100
type(n1)
# Out:
# int

# %% [markdown]
# -if we want to know any type of data or varibale we will use
# **type inbuilt funcation**

# %% [markdown]
# **float**
# *-decimal values representations*

# %%
n2=100.45
type(n2)
# Out:
# float

# %% [markdown]
# **hightes data type will be flot when we are taking about number**

# %% [markdown]
# *one bad thing 1.35677889888*

# %% [markdown]
# **exponential data**

# %%
1e+1
#<1e> mens 1 
#1*<10>
# Out:
# 10.0

# %%
1e+2
# Out:
# 100.0

# %%
1e+3
# Out:
# 1000.0

# %%
3e+4
# Out:
# 30000.0

# %%
1e+1 #1*10
2e+2 #2*100
3e+3 #3*1000
4e+4 # 4*10000
# Out:
# 40000.0

# %%
1e1
# Out:
# 10.0

# %%
2e2
# Out:
# 200.0

# %%
3e3
# Out:
# 3000.0

# %%
4e4
# Out:
# 40000.0

# %% [markdown]
# *e+ also will work and 1e1, 2e2, 3e3 will also work**

# %%
1e+1,1e-1
# Out:
# (10.0, 0.1)

# %%
2e+2,2e-2
# Out:
# (200.0, 0.02)

# %%
1e1,1e/1
# Out:
#   Cell In[19], line 1
#     1e1,1e/1
#         ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **string**

# %%
knapur
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 knapur
#
# NameError: name 'knapur' is not defined

# %%
'Kanpur'
# Out:
# 'Kanpur'

# %%
city='Kanpur' #single Quote
print(city)
type(city)
# Out:
# Kanpur
# str

# %%
Name="avinash"
type(Name)
# Out:
# str

# %%
drgree="b.A' # not sloded
# Out:
#   Cell In[27], line 1
#     drgree="b.A' # not sloded
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s2='Hello  '
len(s2)
# Out:
# 7

# %% [markdown]
# **when ever you are using print fucation be crea full and it will remove space or extrct cahr from start and end**

# %%
s1='hello'
s2='hello world'
print(s1)
print(s2)
# Out:
# hello
# hellow world

# %%
'I like "python"'
# Out:
# 'I like "python"'

# %%
print('I like "python"')
# Out:
# I like "python"

# %% [markdown]
# ##if you like to highlight any word then you can use the "" ##

# %% [markdown]
# -sting can be **single quotes**
# -string can be ** double quote**
# -python by defualt use ** single quote** only

# %% [markdown]
# ** doc string**

# %% [markdown]
# **DOC STRING**

# %%
"""I need to write hi, how are # pass
I am good"""
# Out:
# 'i nee dto write hi how are \ni am good'

# %%
"Hello, how are you
I am good" # fail
'Hello, how are you
I am good'. # fail

# %%
-but trip[le quptes are not recomended
-triple quotes are used to communicate the information
- if any user writes triple quotes ( as in VS code, there are no markdown options in that case, using """ we are passing the information about the code"""

# %%
import os
os.getcwd() # shift +tab will give the Docstring about this fucation
# Out:
# 'C:\\Users\\avina\\OneDrive\\Naresh IT\\Python 1 Basic'

# %% [markdown]
# **boolean data Type**

# %%
int
str
bool

# %%
-true mean 1: on
-fales means 0 : off
-some tthing is not avilable means off

# %%
val1=True
type(val1)
# Out:
# bool

# %%
val2=False
type(val2)
# Out:
# bool

# %%
v1=True #bool
s1="True" # Str
true=10 #varibale
type(v1),type(s1),type(true)
# Out:
# (bool, str, int)

# %%
-int
-flot
-str
-bool

# %% [markdown]
# **TypeCasting**
