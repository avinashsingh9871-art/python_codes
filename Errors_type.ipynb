# %%
-syntax error: A SyntaxError occurs when the Python code does not follow the correct grammar rules.

-name error: A NameError occurs when a variable or function is used before it is defined.

-type error: A TypeError occurs when an operation is performed on incompatible data types.

-value error: A ValueError occurs when the correct data type is used, but the value is invalid.

-zero division error: A ZeroDivisionError occurs when a number is divided by zero.

-model not found error: A ModuleNotFoundError occurs when Python cannot find the specified module.

-attribute error: An AttributeError occurs when you try to access a method or property that does not exist in an object or module.

# %%
print('help)
# Out:
#   Cell In[2], line 1
#     print('help)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
n1=eval(input('enter the number:))
# Out:
#   Cell In[4], line 1
#     n1=eval(input('enter the number:))
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#name errro 
india
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #name errro
# ----> 2 india
#
# NameError: name 'india' is not defined

# %%
india='greate'

# %%
#type error
100+'avinash'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #type error
# ----> 2 100+'avinash'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#VALUE error
int('apple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #VALUE error
# ----> 2 int('apple')
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
#divion error
10/2
# Out:
# 5.0

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
#model error
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
#attribute error
randon.virat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 randon.virat
#
# NameError: name 'randon' is not defined

# %%
#module not found
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 #module not found
# ----> 2 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
#we need to install 
pip install

import random
#mens
pip install random

import time
pip install time

import os
pip install os

# %%
#pip install opencv-python
#go to Anaconda prompt, paste the OpenCV-Python pip install opencv-python
#

import cv2

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\avina\\OneDrive\\Naresh IT\\Python 1 Basic'

# %%
#if you still face errro then restart the kernel first and run again

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import workcloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import workcloud
#
# ModuleNotFoundError: No module named 'workcloud'

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
