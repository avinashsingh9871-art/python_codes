# %%
import os

# %%
os.getcwd() # bracket open and bracket close are musts; if you miss the function brackets, it will give two indications. 
#-**Fucation**
#**bound Mathod**
# Out:
#   Cell In[4], line 2
#     -**Fucation**
#      ^
# SyntaxError: invalid syntax

# %%
import os
os.getcwd() # help to get the location of the file. CWD means current working directory
# Out:
# 'C:\\Users\\avina\\OneDrive\\Naresh IT\\Python 1 Basic'

# %% [markdown]
# #CWD

# %% [markdown]
# ##Cureent Working Directory

# %%
#write one program take 3 number and finds the average
Number_1=30
Number_2=40
Number_3=60
Number_4=(Number_1+Number_2+Number_3)/3
Number_4
# Out:
# 43.333333333333336

# %%
pi=3.14
radius=20
area=pi*radius*radius
print(area)
# Out:
# 1256.0

# %%
length=10
breadth=20
area=length*breadth
print(area)
# Out:
# 200

# %%
bill_amount=500
tipp_amount=300
total_amount=bill_amount+tipp_amount
print(total_amount)
# Out:
# 800

# %%
salary=100000
tax_parsent=10
tax=salary*tax_parsent/100
print(tax)
# Out:
# 10000.0

# %%
sal=12000
Tax_percent=12
total_tax=sal*Tax_percent/100
print(total_tax)
# Out:
# 1440.0

# %%
math=87
science=90
english=80
total_marks=math+science+english
print(total_marks)
# Out:
# 257

# %%
#shoping total
item_1=400
item_2=500
item_3=600
total_item_amount=item_1+item_2+item_3
print(total_item_amount)
# Out:
# 1500

# %% [markdown]
# **round**

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round(23.56)
# Out:
# 24

# %%
round(9.768)
# Out:
# 10

# %%
round(9.567,1)
# Out:
# 9.6

# %%
round(9.5638,2)
# Out:
# 9.56

# %%
round(9.345678,3)
#9.34
# Out:
# 9.346
