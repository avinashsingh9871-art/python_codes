# %%
a=10
a

# %%
a=20
print(a)

# %% [markdown]
# -print is used only top see the answers

# %%
a=10
b=20
a #10
b #20
print(a)
print(b)

# %% [markdown]
# a=10
# b=20
# a,b

# %%
a=10
b=20
a,b

# %%
a=10 # W
b=20 #W
#a,b=30 not work
a,b=40,50 #W
a=60,70 #W

# %%
a,b=40,50
print(a)
print(b)

# %%
a=60,70
print(a)

# %% [markdown]
# ## Variables

# %% [markdown]
# -vari
# -varrii
# -varibale means will chnage the values also store teh values

# %%
nunmber=100
number=200
age=15
age=20

# %%
a=60,70 # two values are assigend into one variables 
# paython dev aimplated as this is work

# %%
(60,70)

# %%
number=100
Number=200

# %%
Number

# %%
number=100
Number=200
NUMber=300
Number123=400

# %%
Number123
# Out:
# 400

# %%
123Numb=500 #not work
# Out:
#   Cell In[3], line 1
#     123Numb=500 #not work
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# -SyntaxError some starandered is not followed

# %%
nunmber+Number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 nunmber+Number
#
# NameError: name 'nunmber' is not defined

# %%
100/0

# %% [markdown]
# -logical error

# %%
number=100 #W
Number=200 #W
NUMber=300 #W
Number123=400 #W
123number=500 #F
number$one=600 #F
# Out:
#   Cell In[5], line 5
#     123number=500 #F
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# number@1
# Number%12
# Number %1
# -all fail as we are using spaical correcter

# %%
number_one=100 #under " _"will work
number_one
# Out:
# 100

# %% [raw]
# number one =900 # only space will not work

# %%
name=Avinash # name is not difened
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 name=Avinash # name is not difened
#
# NameError: name 'Avinash' is not defined

# %%
n1=100
n2=n1
print(n2)
# Out:
# 100

# %% [markdown]
# #black colur allways Varibales

# %%
name='Avinash'
name
# Out:
# 'Avinash'

# %%
number =100 #W
number =200 #W
Number=400 #W
Number_one=500 #W
_=700 #W
number%one=100 #F SY
123number=900 #F SY
Nam=virat #F Logic
Name='name' #W
# Out:
#   Cell In[10], line 7
#     123number=900 #F SY
#       ^
# SyntaxError: invalid decimal literal

# %%
if=100 # 
else
True
False
for
while
print
    # keyword we can use is for variable names inbuilt function
# Out:
#   Cell In[11], line 1
#     if=100 #
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##Inbuilt Function

# %%
print()
len()
sum()
min()
max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 print()
# ----> 2 len()
#       3 sum()
#       4 min()
#
# TypeError: len() takes exactly one argument (0 given)

# %%
l={1,2,3,4,5}
sum(l)
# Out:
# 15

# %%
max(l)
# Out:
# 5

# %%
min(l)
# Out:
# 1

# %% [markdown]
# #black means Varibale , red means String , greem means spl pupose
