# %%
a=1
b=2
c=a+b
c
# Out:
# 3

# %%
a=12
b=13
c=a+b
c
# Out:
# 25

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 number
#
# NameError: name 'number' is not defined

# %%
a
# Out:
# 10

# %%
avinash
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 avinash
#
# NameError: name 'avinash' is not defined

# %%
avinash=100

# %%
avinash
# Out:
# 100

# %%
n1=100

# %%
n1
# Out:
# 100

# %%
n2=100

# %%
n2
# Out:
# 100

# %%
#code cell indicates square bracket before cell
#if the square breaket is empty means the cell did not run
#when we run the cell there is a number available in the square bracket

# %%
#kernal show white : ideal state
#kernal shows Black : he is busy
#do not give more work
#kernal show red : finishied

# %%
print('good morning')
# Out:
# good morning

# %%
import time
time.sleep(5)
print('Good Morning')
# Out:
# Good Morning

# %%
a=10
import time
time.sleep(5)
print('Good Morning')
# Out:
# Good Morning

# %% [markdown]
# Jupyter notebook is used for:
# 1: you can use for the code
# 2: We can also use it for writing the information
# To make it work, you need to go for markdown mode = information without #

# %% [markdown]
# slect the cell go to top and drop down of code selec the markdown and then immeditely the square breaket will be gone this will take you to mark down mode

# %% [markdown]
# short cut for code mode to markdown mode is esc +m

# %% [markdown]
# Markdown to to code mode is esc +y

# %% [markdown]
# # Python

# %% [markdown]
# ### Python

# %% [markdown]
# # Python

# %% [markdown]
# to make is hder you nee dto use # Paython with Sapce and ## will take about the size then esc+m and shift enter

# %% [markdown]
# - Python is looking foor code

# %% [markdown]
# # how to paste image

# %% [markdown]
# <img src="https://assets.aboutamazon.com/dims4/default/e73bc85/2147483647/strip/true/crop/4093x2304+7+0/resize/1240x698!/quality/90/?url=https%3A%2F%2Famazon-blogs-brightspot.s3.amazonaws.com%2F36%2F59%2Feba4adcc4f88a972b5639ed1dde0%2Fadobestock-712831308.jpeg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1240px; height: 315px; margin: 0px; width: 559px;" alt="AWS launches responsible generative AI community in Singapore - About  Amazon Singapore" jsname="kn3ccd">

# %% [markdown]
# Go To google get any impage inspact that imgae and go to eidt it copy the path come back to Jyupetier note book and paste its now esc +M and sfit + enter

# %% [markdown]
# <img src="https://edure.in/wp-content/uploads/2025/02/ai-tools.webp" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1792px; height: 319px; margin: 0px; width: 558px;" alt="Top AI Tools For Freshers to get a job in 2025 - edure" jsname="kn3ccd">

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\avina\\OneDrive\\Naresh IT\\Python 1 Basic'
