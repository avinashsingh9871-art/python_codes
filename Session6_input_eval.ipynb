# %%
number1=100 # hardcoded values
number2=200 # hardcoded values
number1+number2
# Out:
# 300

# %%
application app # frount end
backend the code will run

# %% [markdown]
# **input**

# %%
input
-funcation
-bound mathod
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000002090D615E80>>

# %%
number1=float(input('enter number 1'))
number2=float(input('enter number2'))
number1+number2
# Out:
# enter number 1 300
# enter number2 500
# 800.0

# %%
name=input('Enter your name')
Age=int(input('enter you age'))
address=input('give your address')
# Out:
# Enter your name Avinash kumar singh
# enter you age 39
# give your address 1101 d bloack ajnara homes

# %%
input()
input()
input()
# Out:
#  10
#  10
#  20
# '20'

# %%
n1=int(input('enter the n1'))
n2=int(input('enter the n2'))
# Out:
# enter the n1 100
# enter the n2 200.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 n1=int(input('enter the n1'))
# ----> 2 n2=int(input('enter the n2'))
#
# ValueError: invalid literal for int() with base 10: '200.5'

# %%
n1=float(input('enter the n1'))
n2=float(input('enter the n2'))
n1+n2
# Out:
# enter the n1 200
# enter the n2 300.5
# 500.5

# %% [markdown]
# **eval**

# %% [markdown]
# #evaluate you need not to worry you nee dto use int or float directly will use eval

# %%
n1=eval(input('enter the n1'))
n2=eval(input('enter the n2'))
n1+n2
# Out:
# enter the n1 10.345
# enter the n2 3456.00
# 3466.345

# %%
n1=eval(input('enter the n1'))
n2=eval(input('enter the n2'))
n1+n2
# Out:
# enter the n1 100
# enter the n2 100.5
# 200.5

# %%
n1=eval(input('Enter number n1'))
n2=eval(input('Enter number n2'))
n3=n1+n2
int(n3)
# Out:
# Enter number n1 10
# Enter number n2 13.0
# 23

# %%
n1=eval(input('Enter number n1'))
n2=eval(input('Enter number n2'))
n3=eval(input('Enter number n3'))
n4=(n1+n2+n3)/3
round(n4,3)
# Out:
# Enter number n1 400
# Enter number n2 400
# Enter number n3 600
# 466.667

# %%
Bill_Amount=eval(input('Enter the bill amount:'))
Tip_Amount=eval(input('Enter the Tip Amount:'))
Total_bill=Bill_Amount+Tip_Amount
print(round(Total_bill))
print(Total_bill)
# Out:
# Enter the bill amount: 345.60
# Enter the Tip Amount: 20
# 366
# 365.6

# %%
Salary=eval(input('Enter the Total Sal:'))
Tax_percent=eval(input('Enter tax Percentage:'))
Tax=Salary*Tax_percent/100
print(Tax)
# Out:
# Enter the Total Sal: 200000
# Enter tax Percentage: 30
# 60000.0
